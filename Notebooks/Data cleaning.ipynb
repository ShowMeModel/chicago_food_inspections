# %% [markdown]
# # Chicago food inspections project

# %% [markdown]
# ## Exploratory data analysis

# %% [markdown]
# ### Prepare data science tools

# %%
import numpy as np
import pandas as pd

# %%
import dask.dataframe as dd

# %%
import pandas_profiling

# %%
import plotly.express as px

# %%
import pandas_dedupe

# %% [markdown]
# ### Read data

# %% [markdown]
# We're first trying to read data from the Food Inspections dataset - https://data.cityofchicago.org/Health-Human-Services/Food-Inspections/4ijn-s7e5/data - any supplementary data data will be read later on (e.g. weather conditions or socio-economical data)

# %%
df = dd.read_csv('Food_Inspections_general_201911.csv', 
                 dtype={'License #': 'Int64',
                        'Zip': 'Int64'})

# The lack of NaN rep in integer columns is a pandas "gotcha", 
# but it's fixable with a new type Int64Dtype

# %% [markdown]
# ### List of columns

# %%
df.columns
# Out:
# Index(['Inspection ID', 'DBA Name', 'AKA Name', 'License #', 'Facility Type',
#        'Risk', 'Address', 'City', 'State', 'Zip', 'Inspection Date',
#        'Inspection Type', 'Results', 'Violations', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %% [markdown]
# ### View first rows

# %% [markdown]
# First glance at the data. Surprisingly, most of the data is un-anonimized, meaning it's possible to identify the exact restaurant which was audited.

# %%
df.head(5)
# Out:
#    Inspection ID      DBA Name      AKA Name  License # Facility Type  \
# 0        2345699   JET'S PIZZA   JET'S PIZZA    2163956    Restaurant
# 1        2345619        JAIPUR        JAIPUR    2694084    Restaurant
# 2        2345616  VIP FIT CLUB  VIP FIT CLUB    2446547    Restaurant
# 3        2345602   VELVET TACO   VELVET TACO    2652941    Restaurant
# 4        2345603   VELVET TACO   VELVET TACO    2652943    Restaurant
#
#               Risk               Address     City State    Zip  \
# 0  Risk 2 (Medium)   2811 N ASHLAND AVE   CHICAGO    IL  60657
# 1    Risk 1 (High)    738 W RANDOLPH ST   CHICAGO    IL  60661
# 2  Risk 2 (Medium)  3426 W DIVERSEY AVE   CHICAGO    IL  60647
# 3     Risk 3 (Low)   2309 N LINCOLN AVE   CHICAGO    IL  60614
# 4     Risk 3 (Low)   2309 N LINCOLN AVE   CHICAGO    IL  60614
#
#   Inspection Date Inspection Type             Results  \
# 0      11/15/2019         Canvass  Pass w/ Conditions
# 1      11/14/2019         Canvass                Pass
# 2      11/14/2019       Complaint                Fail
# 3      11/14/2019         License                Fail
# 4      11/14/2019         License                Fail
#
#                                           Violations   Latitude  Longitude  \
# 0  1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...  41.932766 -87.668262
# 1                                                NaN  41.884518 -87.647304
# 2  1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...  41.932069 -87.713294
# 3                                                NaN  41.923953 -87.646462
# 4                                                NaN  41.923953 -87.646462
#
#                                    Location
# 0   (-87.66826200882875, 41.93276573571165)
# 1   (-87.64730383120978, 41.88451799637232)
# 2  (-87.71329441237397, 41.932068626464286)
# 3     (-87.6464616293504, 41.9239529807269)
# 4     (-87.6464616293504, 41.9239529807269)

# %% [markdown]
# Some data is unstructured, especially in text columns like 'Violations', which leaves an opportunity to use NLP tools (for gathering additional information from text). Next, this data has an (inspection) date column, which makes for some time-series analysis.

# %% [markdown]
# ### Get data types of columns

# %%
df.info()
# Out:
# <class 'dask.dataframe.core.DataFrame'>
# Columns: 17 entries, Inspection ID to Location
# dtypes: Int64(2), object(12), float64(2), int64(1)

# %% [markdown]
# Many columns are text (represented by the 'object' type)

# %%
df.dtypes
# Out:
# Inspection ID        int64
# DBA Name            object
# AKA Name            object
# License #            Int64
# Facility Type       object
# Risk                object
# Address             object
# City                object
# State               object
# Zip                  Int64
# Inspection Date     object
# Inspection Type     object
# Results             object
# Violations          object
# Latitude           float64
# Longitude          float64
# Location            object
# dtype: object

# %% [markdown]
# ### Number of rows

# %%
f'There are {len(df):,} rows in dataset and {len(df.columns)} columns'
# Out:
# 'There are 195,979 rows in dataset and 17 columns'

# %% [markdown]
# ### Basic reconnaissance analysis

# %% [markdown]
# #### Use random sample

# %%
df_5p = df.sample(frac=0.05).compute()
f'Sample size is {len(df_5p)}'
# Out:
# 'Sample size is 9799'

# %%
df_5p.profile_report(minify_html=True, use_local_assets=True)

# %% [markdown]
# ### Basic cleaning and checks

# %% [markdown]
# #### License ID

# %% [markdown]
# Q: Does a license ID uniquely identifies an establishment?

# %%
# df.groupby(['License #'])
df.groupby('License #')['DBA Name'].nunique().nlargest(10).compute()
# Out:
# License #
# 0          229
# 14616        7
# 1354323      5
# 1514802      4
# 1196         3
# 1806         3
# 1932         3
# 12141        3
# 17464        3
# 21943        3
# Name: DBA Name, dtype: int64

# %% [markdown]
# A: Yes, but restaurant names require some fixing. Also, the license type may change in time.

# %% [markdown]
# #### Empty license number

# %%
df[df['License #'].isin([0, None, ])].head(50)
# Out:
#        Inspection ID                                     DBA Name  \
# 187          2315561                  DORE EARLY CHILDHOOD CENTER
# 893          2300450                                       SUBWAY
# 1049         2293545                                       SUBWAY
# 1584         2283080                  CHURCH OF THE THREE CROSSES
# 3001         2222226                        BIRRIA OCOTLAN MEZCAL
# 3359         2185028                 IMMACULATE CONCEPTION CHURCH
# 3686         2176741                 BELMONT PLACE SENIOR HOUSING
# 4092         2159749                           LITTLE BLACK PEARL
# 4882         2116707              MRS. T'S SOUTHERN FRIED CHICKEN
# 5507         2081887                        ASADO COFFEE ROASTERS
# 5648         2079021  ST. ATHANASIOS & JOHN GREEK ORTHODOX CHURCH
# 5715         2078533                          Greater Rock Church
# 6243         2059984                                    LOVE TACO
# 6461         2050319                                   BBQ SUPPLY
# 6672         2028350                  CHURCH OF THE THREE CROSSES
# 8417         1953270        BIBLEWAY APOSTOLIC FAITH CHURCH, INC.
# 8549         1950352                            ST. JEROME PARISH
# 8554         1950324        BIBLEWAY APOSTOLIC FAITH CHURCH, INC.
# 8587         1949094                SAINT DOROTHY CATHOLIC CHURCH
# 8589         1949092                     PROVIDENCE OF GOD CHURCH
# 9203         1931677                        ASSUMPTION BVM CHURCH
# 10018        1632335                             KINGS AND QUEENS
# 10023        1632323                          TAQUERIA LA CAPITAL
# 11196        1575618                             ST. PAULS CHURCH
# 11668        1482864                            ST. JEROME PARISH
# 11692        1561236                                MARTINI RANCH
# 11962        1547017                                        WONUT
# 12090        1528262                           LITTLE BLACK PEARL
# 12093        1546262                        ASSUMPTION BVM CHURCH
# 12129        1538087                      MIDWEST BUDDHIST TEMPLE
# 12670        1453794                    LA FLOR DE MAYO ICE CREAM
# 12693        1528212       INTERNATIONAL CHILDREN'S CRISIS CENTER
# 13177        1512845                                  HERBAL LIFE
# 13456        1501398                                   LAS QUECAS
# 13739        1480316                                   RIB LADY 2
# 14477        1490391                          ST. TERESA OF AVILA
# 14637        1473701                          ST. TERESA OF AVILA
# 15673        1395726                                   LAS QUECAS
# 16504        1199085                             ST. PAULS CHURCH
# 17396        1324467                     OLD ST. PATRICK'S CHURCH
# 17418        1198859             ST. GEORGE GREEK ORTHODOX CHURCH
# 17614        1138912           ANNUNCIATION GREEK ORTHODOX CHURCH
# 17747        1235707                  ALL SAINTS EPISCOPAL CHURCH
# 18851        1305208                          BELLY UP RESTAURANT
# 19208        1158436                                      UNKNOWN
# 19251        1234559                               GRILL MASTER'S
# 19342        1234544                               GRILL MASTER'S
# 19554        1202335                                     PRIMO #2
# 19623        1229649                              COMPLETELY NUTS
# 19654        1229587                           NORMA'S MINI STORE
#
#                                             AKA Name  License #  \
# 187                      DORE EARLY CHILDHOOD CENTER          0
# 893                                           SUBWAY          0
# 1049                                          SUBWAY          0
# 1584                     CHURCH OF THE THREE CROSSES          0
# 3001                           BIRRIA OCOTLAN MEZCAL          0
# 3359                                             NaN          0
# 3686                    BELMONT PLACE SENIOR HOUSING          0
# 4092                              LITTLE BLACK PEARL          0
# 4882                 MRS. T'S SOUTHERN FRIED CHICKEN          0
# 5507                           ASADO COFFEE ROASTERS          0
# 5648   ST. ATHANASIOS & JOHN  GREEK OROTHODOX CHURCH          0
# 5715                             Greater Rock Church          0
# 6243                                       LOVE TACO          0
# 6461                                      BBQ SUPPLY          0
# 6672                     CHURCH OF THE THREE CROSSES          0
# 8417                 BIBLEWAY APOSTOLIC FAITH CHURCH          0
# 8549                                      ST. JEROME          0
# 8554                 BIBLEWAY APOSTOLIC FAITH CHURCH          0
# 8587                   SAINT DOROTHY CATHOLIC CHURCH          0
# 8589                               PROVIDENCE OF GOD          0
# 9203                           ASSUMPTION BVM CHURCH          0
# 10018                               KINGS AND QUEENS          0
# 10023                            TAQUERIA LA CAPITAL          0
# 11196                               ST. PAULS CHURCH          0
# 11668                                     ST. JEROME          0
# 11692                                  MARTINI RANCH          0
# 11962                                          WONUT          0
# 12090                             LITTLE BLACK PEARL          0
# 12093                          ASSUMPTION BVM CHURCH          0
# 12129                        MIDWEST BUDDHIST TEMPLE          0
# 12670                      LA FLOR DE MAYO ICE CREAM          0
# 12693                            ALL FAITH  PAVILION          0
# 13177                                    HERBAL LIFE          0
# 13456                                     LAS QUECAS          0
# 13739                                     RIB LADY 2          0
# 14477                            ST. TERESA OF AVILA          0
# 14637                            ST. TERESA OF AVILA          0
# 15673                                     LAS QUECAS          0
# 16504                               ST. PAULS CHURCH          0
# 17396                       OLD ST. PATRICK'S CHURCH          0
# 17418               ST. GEORGE GREEK ORTHODOX CHURCH          0
# 17614             ANNUNCIATION GREEK ORTHODOX CHURCH          0
# 17747                    ALL SAINTS EPISCOPAL CHURCH          0
# 18851                                            NaN          0
# 19208                                            NaN          0
# 19251                                            NaN          0
# 19342                                            NaN          0
# 19554                                       PRIMO #2          0
# 19623                                COMPLETELY NUTS          0
# 19654                             NORMA'S MINI STORE          0
#
#                  Facility Type             Risk                   Address  \
# 187                     School    Risk 1 (High)        6108 S Natoma AVE
# 893                 Restaurant    Risk 1 (High)       4771 N LINCOLN AVE
# 1049                Restaurant    Risk 1 (High)       4771 N LINCOLN AVE
# 1584             Special Event  Risk 2 (Medium)          333 W WISCONSIN
# 3001                Restaurant    Risk 1 (High)         3011 W CERMAK RD
# 3359      CHURCH/SPECIAL EVENT    Risk 1 (High)    8756 S COMMERICAL AVE
# 3686            Long Term Care    Risk 1 (High)       4645 W BELMONT AVE
# 4092                    School  Risk 2 (Medium)           1060 E 47TH ST
# 4882                Restaurant    Risk 1 (High)          3343 N BROADWAY
# 5507                Restaurant  Risk 2 (Medium)        22 E JACKSON BLVD
# 5648   CHURCH (SPECIAL EVENTS)    Risk 1 (High)        4200 N KEELER AVE
# 5715             Special Event  Risk 2 (Medium)  718 S INDEPENDENCE BLVD
# 6243                Restaurant    Risk 1 (High)            109 E 51ST ST
# 6461                Restaurant    Risk 1 (High)       6948 N WESTERN AVE
# 6672             Special Event  Risk 2 (Medium)          333 W WISCONSIN
# 8417             Special Event    Risk 1 (High)       1807 S KOSTNER AVE
# 8549            CHURCH KITCHEN    Risk 1 (High)              1709 W LUNT
# 8554             Special Event    Risk 1 (High)       1807 S KOSTNER AVE
# 8587                    CHURCH    Risk 1 (High)            450 E 78TH ST
# 8589             Special Event  Risk 2 (Medium)            717 W 18th ST
# 9203             Special Event    Risk 1 (High)    2434 S CALIFORNIA AVE
# 10018              SOCIAL CLUB     Risk 3 (Low)         358 S PULASKI RD
# 10023               Restaurant    Risk 1 (High)           3508 W 63RD ST
# 11196            Special Event  Risk 2 (Medium)        2335 N ORCHARD ST
# 11668           CHURCH KITCHEN    Risk 1 (High)              1709 W LUNT
# 11692                      NaN    Risk 1 (High)        311 W CHICAGO AVE
# 11962               Restaurant  Risk 2 (Medium)           835 N MICHIGAN
# 12090                   School  Risk 2 (Medium)           1060 E 47TH ST
# 12093            Special Event    Risk 1 (High)    2434 S CALIFORNIA AVE
# 12129                      NaN    Risk 1 (High)          435 W MENOMONEE
# 12670               Restaurant    Risk 1 (High)         1819 W CERMAK RD
# 12693           Long Term Care    Risk 1 (High)         3500 S GILES AVE
# 13177         HERBAL LIFE SHOP  Risk 2 (Medium)           1854 W 18TH ST
# 13456               Restaurant    Risk 1 (High)    2500 S CHRISTIANA AVE
# 13739               Restaurant    Risk 1 (High)         4203 W CERMAK RD
# 14477                   CHURCH    Risk 1 (High)       1950 N KENMORE AVE
# 14637                   CHURCH    Risk 1 (High)       1950 N KENMORE AVE
# 15673               Restaurant    Risk 1 (High)    2500 S CHRISTIANA AVE
# 16504            Special Event  Risk 2 (Medium)        2335 N ORCHARD ST
# 17396                   Church  Risk 2 (Medium)           700 W ADAMS ST
# 17418            Special Event    Risk 1 (High)     2701 N SHEFFIELD AVE
# 17614                   CHURCH  Risk 2 (Medium)       1017 N LA SALLE DR
# 17747                   CHURCH  Risk 2 (Medium)     4550 N HERMITAGE AVE
# 18851                      NaN    Risk 1 (High)          1999 E HAYES DR
# 19208                      NaN              NaN               300 E 47TH
# 19251                      NaN    Risk 1 (High)            512 E 71ST ST
# 19342                      NaN    Risk 1 (High)            512 E 71ST ST
# 19554    Mobile Food Dispenser    Risk 1 (High)           2600 W 35TH ST
# 19623          Navy Pier Kiosk     Risk 3 (Low)          600 E GRAND AVE
# 19654            Grocery Store     Risk 3 (Low)           2059 W 21ST ST
#
#           City State    Zip Inspection Date          Inspection Type  \
# 187    CHICAGO    IL  60638      10/09/2019                  Canvass
# 893    CHICAGO    IL  60625      06/28/2019                  Canvass
# 1049   CHICAGO    IL  60625      06/13/2019                  Canvass
# 1584   CHICAGO    IL  60614      04/12/2019                  Canvass
# 3001   CHICAGO    IL  60623      09/12/2018                  Canvass
# 3359   CHICAGO    IL  60617      07/25/2018                  Canvass
# 3686   CHICAGO    IL  60641      06/05/2018     Short Form Complaint
# 4092   CHICAGO    IL  60653      04/10/2018                  Canvass
# 4882   CHICAGO    IL  60657      12/06/2017                  Canvass
# 5507   CHICAGO    IL  60604      09/12/2017    Canvass Re-Inspection
# 5648   CHICAGO    IL  60641      08/25/2017    Canvass Re-Inspection
# 5715   CHICAGO    IL  60624      08/16/2017                  Canvass
# 6243   CHICAGO    IL  60615      06/09/2017  Complaint Re-Inspection
# 6461   CHICAGO    IL  60645      05/12/2017                Complaint
# 6672   CHICAGO    IL  60614      04/14/2017                  Canvass
# 8417   CHICAGO    IL  60623      08/29/2016    Canvass Re-Inspection
# 8549   CHICAGO    IL  60626      08/15/2016    Canvass Re-Inspection
# 8554   CHICAGO    IL  60623      08/12/2016                  Canvass
# 8587   CHICAGO    IL  60619      08/10/2016                  Canvass
# 8589   CHICAGO    IL  60608      08/10/2016    Canvass Re-Inspection
# 9203   CHICAGO    IL  60608      05/26/2016                  Canvass
# 10018  CHICAGO    IL  60624      02/26/2016    Canvass Re-Inspection
# 10023  CHICAGO    IL  60629      02/26/2016                  Canvass
# 11196  CHICAGO    IL  60614      09/16/2015                  Canvass
# 11668  CHICAGO    IL  60626      07/17/2015                  Canvass
# 11692  CHICAGO    IL  60654      07/15/2015                  Canvass
# 11962  CHICAGO    IL  60611      06/11/2015                  Canvass
# 12090  CHICAGO    IL  60653      05/21/2015                  Canvass
# 12093  CHICAGO    IL  60608      05/21/2015                  Canvass
# 12129  CHICAGO    IL  60614      05/15/2015                  Canvass
# 12670  CHICAGO    IL  60608      03/03/2015                  Canvass
# 12693  CHICAGO    IL  60653      02/26/2015                  Canvass
# 13177  CHICAGO    IL  60608      12/10/2014    Canvass Re-Inspection
# 13456  CHICAGO    IL  60623      10/31/2014                  Canvass
# 13739  CHICAGO    IL  60623      09/29/2014                  Canvass
# 14477  CHICAGO    IL  60614      07/08/2014    Canvass Re-Inspection
# 14637  CHICAGO    IL  60614      06/13/2014                  Canvass
# 15673  CHICAGO    IL  60623      01/27/2014  Complaint Re-Inspection
# 16504  CHICAGO    IL  60614      09/17/2013                  Canvass
# 17396  CHICAGO    IL  60661      05/16/2013                  Canvass
# 17418  CHICAGO    IL  60614      05/14/2013                  Canvass
# 17614  CHICAGO    IL  60610      04/16/2013                  Canvass
# 17747  CHICAGO    IL  60640      03/27/2013                  Canvass
# 18851  CHICAGO    IL  60637      10/03/2012     Short Form Complaint
# 19208  CHICAGO    IL  60653      08/15/2012                Complaint
# 19251  CHICAGO    IL  60619      08/09/2012                Complaint
# 19342  CHICAGO    IL  60619      07/26/2012                Complaint
# 19554  CHICAGO    IL  60632      06/25/2012     Short Form Complaint
# 19623  CHICAGO    IL  60611      06/14/2012                  Canvass
# 19654  CHICAGO    IL  60608      06/13/2012                  Canvass
#
#                     Results  \
# 187                    Pass
# 893         Out of Business
# 1049                   Fail
# 1584                   Pass
# 3001                   Fail
# 3359     Pass w/ Conditions
# 3686     Pass w/ Conditions
# 4092                   Pass
# 4882        Out of Business
# 5507                   Pass
# 5648                   Pass
# 5715                   Pass
# 6243                   Pass
# 6461                   Fail
# 6672                   Pass
# 8417               No Entry
# 8549                   Pass
# 8554               No Entry
# 8587                   Pass
# 8589                   Pass
# 9203                   Fail
# 10018              No Entry
# 10023       Out of Business
# 11196                  Pass
# 11668                  Pass
# 11692       Out of Business
# 11962                  Fail
# 12090    Pass w/ Conditions
# 12093                  Pass
# 12129                  Pass
# 12670       Out of Business
# 12693                  Pass
# 13177       Out of Business
# 13456       Out of Business
# 13739       Out of Business
# 14477                  Pass
# 14637                  Fail
# 15673                  Pass
# 16504                  Pass
# 17396                  Pass
# 17418                  Pass
# 17614    Pass w/ Conditions
# 17747                  Pass
# 18851              No Entry
# 19208  Business Not Located
# 19251              No Entry
# 19342              No Entry
# 19554                  Fail
# 19623                  Pass
# 19654       Out of Business
#
#                                               Violations   Latitude  \
# 187                                                  NaN  41.780927
# 893                                                  NaN  41.968506
# 1049   1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...  41.968506
# 1584   55. PHYSICAL FACILITIES INSTALLED, MAINTAINED ...  41.916419
# 3001   2. CITY OF CHICAGO FOOD SERVICE SANITATION CER...  41.851720
# 3359   3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL E...        NaN
# 3686                                                 NaN  41.938758
# 4092   35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.809722
# 4882                                                 NaN  41.943219
# 5507                                                 NaN  41.878336
# 5648                                                 NaN  41.957334
# 5715                                                 NaN  41.871940
# 6243   38. VENTILATION: ROOMS AND EQUIPMENT VENTED AS...  41.801898
# 6461   12. HAND WASHING FACILITIES: WITH SOAP AND SAN...  42.008278
# 6672   36. LIGHTING: REQUIRED MINIMUM FOOT-CANDLES OF...  41.916419
# 8417                                                 NaN  41.856628
# 8549   32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  42.008898
# 8554                                                 NaN  41.856628
# 8587   38. VENTILATION: ROOMS AND EQUIPMENT VENTED AS...  41.753084
# 8589   32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  41.857451
# 9203   22. DISH MACHINES: PROVIDED WITH ACCURATE THER...  41.847222
# 10018  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.875312
# 10023                                                NaN  41.778957
# 11196                                                NaN  41.924693
# 11668  38. VENTILATION: ROOMS AND EQUIPMENT VENTED AS...  42.008898
# 11692                                                NaN  41.896457
# 11962  9. WATER SOURCE: SAFE, HOT & COLD UNDER CITY P...  41.897741
# 12090  3. POTENTIALLY HAZARDOUS FOOD MEETS TEMPERATUR...  41.809722
# 12093                                                NaN  41.847222
# 12129                                                NaN  41.914565
# 12670                                                NaN  41.852126
# 12693  38. VENTILATION: ROOMS AND EQUIPMENT VENTED AS...  41.830985
# 13177                                                NaN  41.857806
# 13456                                                NaN  41.846184
# 13739                                                NaN  41.851366
# 14477                                                NaN  41.917388
# 14637  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.917388
# 15673  38. VENTILATION: ROOMS AND EQUIPMENT VENTED AS...  41.846184
# 16504  40. REFRIGERATION AND METAL STEM THERMOMETERS ...  41.924693
# 17396  38. VENTILATION: ROOMS AND EQUIPMENT VENTED AS...  41.879367
# 17418                                                NaN  41.930918
# 17614  21. * CERTIFIED FOOD MANAGER ON SITE WHEN POTE...  41.901081
# 17747                                                NaN  41.964872
# 18851                                                NaN  41.780239
# 19208                                                NaN  41.809447
# 19251                                                NaN  41.765871
# 19342                                                NaN  41.765871
# 19554  1. SOURCE SOUND CONDITION, NO SPOILAGE, FOODS ...  41.830296
# 19623                                                NaN  41.892094
# 19654                                                NaN  41.853868
#
#        Longitude                                  Location
# 187   -87.787640   (-87.78764008652699, 41.78092716332793)
# 893   -87.688338    (-87.6883380552873, 41.96850625784847)
# 1049  -87.688338    (-87.6883380552873, 41.96850625784847)
# 1584  -87.637601   (-87.63760096984397, 41.91641905854752)
# 3001  -87.700877  (-87.70087724148631, 41.851719660634274)
# 3359         NaN                                       NaN
# 3686  -87.743920   (-87.74392031202537, 41.93875847343951)
# 4092  -87.599389   (-87.59938918300288, 41.80972238714215)
# 4882  -87.644590   (-87.64459003405148, 41.94321903123653)
# 5507  -87.626892  (-87.62689227478914, 41.878336071547935)
# 5648  -87.732733   (-87.73273323577344, 41.95733430720731)
# 5715  -87.720457   (-87.72045686348807, 41.87193979943327)
# 6243  -87.622200   (-87.62220008978774, 41.80189763712391)
# 6461  -87.690299   (-87.6902989251108, 42.008277723075075)
# 6672  -87.637601   (-87.63760096984397, 41.91641905854752)
# 8417  -87.734522    (-87.7345218846495, 41.85662809092877)
# 8549  -87.672651    (-87.67265061077502, 42.0088983888472)
# 8554  -87.734522    (-87.7345218846495, 41.85662809092877)
# 8587  -87.612947   (-87.61294712593383, 41.75308418860929)
# 8589  -87.645477   (-87.64547744304339, 41.85745149119915)
# 9203  -87.695459   (-87.69545910627433, 41.84722223077455)
# 10018 -87.725633    (-87.7256328164783, 41.87531202085823)
# 10023 -87.710827   (-87.71082664189547, 41.77895708746995)
# 11196 -87.646164   (-87.64616383833263, 41.92469260253151)
# 11668 -87.672651    (-87.67265061077502, 42.0088983888472)
# 11692 -87.636181   (-87.63618117278183, 41.89645685790188)
# 11962 -87.623961  (-87.62396131598219, 41.897740856252504)
# 12090 -87.599389   (-87.59938918300288, 41.80972238714215)
# 12093 -87.695459   (-87.69545910627433, 41.84722223077455)
# 12129 -87.640114   (-87.64011355221865, 41.91456539509601)
# 12670 -87.671743   (-87.67174258992257, 41.85212641996553)
# 12693 -87.619484  (-87.61948414664553, 41.830985148321716)
# 13177 -87.673279   (-87.67327895610481, 41.85780570258303)
# 13456 -87.708890   (-87.70888991434978, 41.84618419734266)
# 13739 -87.729766    (-87.72976631700914, 41.8513662093141)
# 14477 -87.654521   (-87.65452119156288, 41.91738750614948)
# 14637 -87.654521   (-87.65452119156288, 41.91738750614948)
# 15673 -87.708890   (-87.70888991434978, 41.84618419734266)
# 16504 -87.646164   (-87.64616383833263, 41.92469260253151)
# 17396 -87.644105   (-87.64410546134096, 41.87936739625875)
# 17418 -87.653653  (-87.65365342053201, 41.930917701476844)
# 17614 -87.632699   (-87.63269935304534, 41.90108084864571)
# 17747 -87.672648    (-87.67264828660348, 41.9648722283692)
# 18851 -87.577636  (-87.57763590871134, 41.780238657236744)
# 19208 -87.619524    (-87.6195240872256, 41.80944685365532)
# 19251 -87.612286  (-87.61228568559252, 41.765871250597435)
# 19342 -87.612286  (-87.61228568559252, 41.765871250597435)
# 19554 -87.690059   (-87.69005861348269, 41.83029606803829)
# 19623 -87.611570  (-87.61156988394656, 41.892094136861786)
# 19654 -87.678219   (-87.67821915483191, 41.85386830200632)

# %% [markdown]
# #### City attribute

# %%
df.City.value_counts().compute()
# Out:
# CHICAGO               195139
# Chicago                  321
# chicago                   97
# CCHICAGO                  46
# SCHAUMBURG                25
#                        ...
# COUNTRY CLUB HILLS         1
# DES PLAINES                1
# GRIFFITH                   1
# alsip                      1
# GLENCOE                    1
# Name: City, Length: 71, dtype: int64

# %% [markdown]
# #### Normalize city names

# %%
def fix_city(df):
    df['City'] = df['City'].map(lambda x: 'CHICAGO' if x in ['Chicago', 'chicago', 'CCHICAGO'] else x)
    return df

# %% [markdown]
# #### State attribute

# %%
df.State.value_counts().compute()
# Out:
# IL    195934
# WI         1
# NY         1
# IN         1
# Name: State, dtype: int64

# %% [markdown]
# #### State other than 'IL' is probably a noise and it'll be removed

# %%
incidents = df.map_partitions(fix_city).compute()
incidents = incidents[incidents.State == 'IL']

# %%
incidents.head(5)
# Out:
#    Inspection ID      DBA Name      AKA Name  License # Facility Type  \
# 0        2345699   JET'S PIZZA   JET'S PIZZA    2163956    Restaurant
# 1        2345619        JAIPUR        JAIPUR    2694084    Restaurant
# 2        2345616  VIP FIT CLUB  VIP FIT CLUB    2446547    Restaurant
# 3        2345602   VELVET TACO   VELVET TACO    2652941    Restaurant
# 4        2345603   VELVET TACO   VELVET TACO    2652943    Restaurant
#
#               Risk               Address     City State    Zip  \
# 0  Risk 2 (Medium)   2811 N ASHLAND AVE   CHICAGO    IL  60657
# 1    Risk 1 (High)    738 W RANDOLPH ST   CHICAGO    IL  60661
# 2  Risk 2 (Medium)  3426 W DIVERSEY AVE   CHICAGO    IL  60647
# 3     Risk 3 (Low)   2309 N LINCOLN AVE   CHICAGO    IL  60614
# 4     Risk 3 (Low)   2309 N LINCOLN AVE   CHICAGO    IL  60614
#
#   Inspection Date Inspection Type             Results  \
# 0      11/15/2019         Canvass  Pass w/ Conditions
# 1      11/14/2019         Canvass                Pass
# 2      11/14/2019       Complaint                Fail
# 3      11/14/2019         License                Fail
# 4      11/14/2019         License                Fail
#
#                                           Violations   Latitude  Longitude  \
# 0  1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...  41.932766 -87.668262
# 1                                                NaN  41.884518 -87.647304
# 2  1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...  41.932069 -87.713294
# 3                                                NaN  41.923953 -87.646462
# 4                                                NaN  41.923953 -87.646462
#
#                                    Location
# 0   (-87.66826200882875, 41.93276573571165)
# 1   (-87.64730383120978, 41.88451799637232)
# 2  (-87.71329441237397, 41.932068626464286)
# 3     (-87.6464616293504, 41.9239529807269)
# 4     (-87.6464616293504, 41.9239529807269)

# %% [markdown]
# ### Identify duplicated establishments

# %%
establishments = incidents[['DBA Name', 'AKA Name', 'Facility Type', 'Address', 'City', 'Zip']]

# %%
establishments['LatLong'] = incidents.apply(lambda x: None if any([pd.isna(x['Latitude']), pd.isna(x['Longitude'])]) else (x['Latitude'], x['Longitude']), axis=1)

# %%
len(establishments)
# Out:
# 195934

# %%
establishments = establishments.drop_duplicates()

# %%
len(establishments)
# Out:
# 32887

# %%
establishments.LatLong.value_counts()
# Out:
# (42.008536400868735, -87.91442843927048)    267
# (41.88743405025222, -87.68184949426895)     188
# None                                        160
# (41.85045102427, -87.65879785567869)        113
# (41.83078366228312, -87.6352957830455)       96
#                                            ...
# (41.90344939527244, -87.66803165380388)       1
# (41.76830760574476, -87.72264592858038)       1
# (41.98467406624727, -87.69692510314671)       1
# (41.713787168999794, -87.53663320988323)      1
# (41.90326646138292, -87.67912669629169)       1
# Name: LatLong, Length: 16815, dtype: int64

# %%
# Initiate deduplication
locations_dedup = pandas_dedupe.dedupe_dataframe(establishments, 
                                                 ['DBA Name', 'AKA Name', 'Facility Type', 
                                                  'Address', 'City', 
                                                  ('Zip', 'Exact'), ('LatLong', 'LatLong', 'has missing')])
# Out:
# importing data ...
# DBA Name : dona maris 2
# AKA Name : dona maris 2
# Facility Type : grocery store
# Address : 3518 w montrose ave
# City : chicago
# Zip : 60618
# LatLong : (41.96119793965089, -87.7164129559992)
#
# DBA Name : wing lee chinese cuisine and cafe corporation
# AKA Name : wing lee chinese cuisine and cafe corporation
# Facility Type : None
# Address : 1810 w montrose ave
# City : chicago
# Zip : 60613
# LatLong : (41.961619281289565, -87.67502882185283)
#
# 0/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished
# starting active labeling...
# n
# DBA Name : 7-eleven
# AKA Name : 7-eleven
# Facility Type : grocery store
# Address : 5206 n western ave
# City : chicago
# Zip : 60625
# LatLong : (41.97612112189385, -87.68930731555461)
#
# DBA Name : 7-eleven 36718b
# AKA Name : 7-eleven
# Facility Type : grocery store
# Address : 3600 w belmont ave
# City : chicago
# Zip : 60618
# LatLong : (41.939325192495275, -87.71746162505319)
#
# 0/10 positive, 1/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# n
# DBA Name : ella vanilla llc
# AKA Name : ella vanilla llc
# Facility Type : shared kitchen user (long term)
# Address : 2217 w crystal st apt 2
# City : chicago
# Zip : 60622
# LatLong : None
#
# DBA Name : taqueria guerrero
# AKA Name : taqueria guerrero
# Facility Type : restaurant
# Address : 2551 w cermak rd
# City : chicago
# Zip : 60608
# LatLong : (41.85186827166058, -87.69007512129495)
#
# 0/10 positive, 2/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# n
# DBA Name : pizzeria calzone
# AKA Name : pizzeria calzone
# Facility Type : restaurant
# Address : 5858 n lincoln ave
# City : chicago
# Zip : 60659
# LatLong : (41.98786035580833, -87.70336737996178)
#
# DBA Name : nancy foods inc
# AKA Name : nancy foods inc
# Facility Type : grocery store
# Address : 12315 s state st
# City : chicago
# Zip : 60628
# LatLong : (41.670252399927904, -87.62227195617474)
#
# 0/10 positive, 3/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# n
# DBA Name : mcdonalds 12785
# AKA Name : mcdonalds (t5 arrival)
# Facility Type : restaurant
# Address : 11601 w touhy ave
# City : chicago
# Zip : 60666
# LatLong : (42.008536400868735, -87.91442843927048)
#
# DBA Name : mcdonalds
# AKA Name : mcdonalds
# Facility Type : None
# Address : 6900 s lafayette ave
# City : chicago
# Zip : 60621
# LatLong : (41.76915533533597, -87.6268126762725)
#
# 0/10 positive, 4/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# n
# DBA Name : bridgeport pasty, llc
# AKA Name : bridgeport pasty
# Facility Type : restaurant
# Address : 3142 s morgan st
# City : chicago
# Zip : 60608
# LatLong : (41.83673163109136, -87.65125761223642)
#
# DBA Name : bridgeport pasty, llc
# AKA Name : bridgeport pasty
# Facility Type : mobile food dispenser
# Address : 3142 s morgan st
# City : chicago
# Zip : 60608
# LatLong : (41.83673163109136, -87.65125761223642)
#
# 0/10 positive, 5/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# y
# DBA Name : czerwony kapturek
# AKA Name : czerwony kapturek
# Facility Type : None
# Address : 7628-7630 w foster ave
# City : chicago
# Zip : 60656
# LatLong : (41.974365531990216, -87.81812421807619)
#
# DBA Name : south shore high no.
# AKA Name : south shore high north
# Facility Type : school
# Address : 7529 s constance (1832e)
# City : charles a hayes
# Zip : 60649
# LatLong : (41.75795594904808, -87.57964647686238)
#
# 1/10 positive, 5/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# n
# DBA Name : gateway newstand
# AKA Name : gateway newstand
# Facility Type : grocery store
# Address : 875 n michigan ave
# City : chicago
# Zip : 60611
# LatLong : (41.898948541729865, -87.62397498768969)
#
# DBA Name : aramark
# AKA Name : aramark
# Facility Type : restaurant
# Address : 875 n michigan ave
# City : chicago
# Zip : 60611
# LatLong : (41.898948541729865, -87.62397498768969)
#
# 1/10 positive, 6/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# n
# DBA Name : pulaski mobil
# AKA Name : mobil
# Facility Type : grocery store
# Address : 2801-2811 s pulaski rd
# City : chicago
# Zip : 60623
# LatLong : (41.84047629775851, -87.72429987820476)
#
# DBA Name : freds mobil
# AKA Name : mobil
# Facility Type : grocery store
# Address : 2801-2811 s pulaski rd
# City : chicago
# Zip : 60623
# LatLong : (41.84047629775851, -87.72429987820476)
#
# 1/10 positive, 7/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# n
# DBA Name : quick bite
# AKA Name : quick bite
# Facility Type : None
# Address : 3901 s dr martin luther king jr dr
# City : chicago
# Zip : 60653
# LatLong : (41.82377697840096, -87.61684857582857)
#
# DBA Name : quick bite
# AKA Name : quick bite
# Facility Type : None
# Address : 3901 s dr martin luther king jr
# City : chicago
# Zip : 60653
# LatLong : None
#
# 1/10 positive, 8/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# y
# DBA Name : dianas daycare center
# AKA Name : dianas daycare center
# Facility Type : daycare above and under 2 years
# Address : 5961 n clark st
# City : chicago
# Zip : 60660
# LatLong : (41.990244301033066, -87.66985749853201)
#
# DBA Name : dianas daycare center llc
# AKA Name : dianas daycare center
# Facility Type : daycare (2 - 6 years)
# Address : 5961 n clark st
# City : chicago
# Zip : 60660
# LatLong : (41.990244301033066, -87.66985749853201)
#
# 2/10 positive, 8/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# y
# DBA Name : illinois sportservice inc
# AKA Name : dipping dots ice cream 2 (540-542)
# Facility Type : kiosk
# Address : 333 w 35th st
# City : chicago
# Zip : 60616
# LatLong : (41.83078366228312, -87.6352957830455)
#
# DBA Name : illinois sportservice inc
# AKA Name : hot dog vienna beef 7 (557)
# Facility Type : restaurant
# Address : 333 w 35th st
# City : chicago
# Zip : 60616
# LatLong : (41.83078366228312, -87.6352957830455)
#
# 3/10 positive, 8/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# n
# DBA Name : 7-eleven
# AKA Name : 7-eleven
# Facility Type : None
# Address : 343 n la salle dr
# City : chicago
# Zip : 60610
# LatLong : (41.88863332889772, -87.63236252748243)
#
# DBA Name : 7-eleven
# AKA Name : 7-eleven
# Facility Type : None
# Address : 343 n la salle st
# City : chicago
# Zip : 60654
# LatLong : (41.88863332889772, -87.63236252748243)
#
# 3/10 positive, 9/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# y
# DBA Name : southport city saloon
# AKA Name : southport city saloon
# Facility Type : restaurant
# Address : 2542-2548 n southport ave
# City : chicago
# Zip : 60614
# LatLong : (41.928296636787316, -87.66357131513206)
#
# DBA Name : southport city saloon
# AKA Name : southport city saloon
# Facility Type : None
# Address : 2548 n southport ave
# City : chicago
# Zip : 60614
# LatLong : (41.928485477764006, -87.66357735760441)
#
# 4/10 positive, 9/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# y
# DBA Name : bambi
# AKA Name : bambi cart cbh 1383
# Facility Type : mobile food dispenser
# Address : 2051 w 47th st
# City : chicago
# Zip : 60609
# LatLong : (41.808395917931094, -87.67672122326663)
#
# DBA Name : bambi
# AKA Name : bambi cart cbh 1385
# Facility Type : mobile food dispenser
# Address : 2051 w 47th st
# City : chicago
# Zip : 60609
# LatLong : (41.808395917931094, -87.67672122326663)
#
# 5/10 positive, 9/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# u
# DBA Name : papa ts italiano
# AKA Name : papa ts italiano truck 5
# Facility Type : mobile food dispenser
# Address : 2843 - 2847 w 63rd st
# City : chicago
# Zip : 60629
# LatLong : (41.778980820715226, -87.69509004304912)
#
# DBA Name : papa ts italiano
# AKA Name : papa ts italiano truck 8
# Facility Type : mobile food dispenser
# Address : 2843 - 2847 w 63rd st
# City : chicago
# Zip : 60629
# LatLong : (41.778980820715226, -87.69509004304912)
#
# 5/10 positive, 9/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# n
# DBA Name : automatic icemakers
# AKA Name : automatic icemakers
# Facility Type : wholesale
# Address : 3725 n talman ave
# City : chicago
# Zip : 60618
# LatLong : (41.9492777002764, -87.69475171075673)
#
# DBA Name : automatic icemakers holding, inc
# AKA Name : automatic icemakers holding, inc
# Facility Type : None
# Address : 3725 n talman ave
# City : chicago
# Zip : 60618
# LatLong : (41.9492777002764, -87.69475171075673)
#
# 5/10 positive, 10/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# y
# DBA Name : kentucky fried chicken 521047
# AKA Name : kentucky fried chicken 521047
# Facility Type : restaurant
# Address : 5230 w madison st
# City : chicago
# Zip : 60644
# LatLong : (41.880465442372845, -87.75634710267644)
#
# DBA Name : mih admin services llc/dba kfc 521047
# AKA Name : kfc
# Facility Type : restaurant
# Address : 5230 w madison st
# City : chicago
# Zip : 60644
# LatLong : (41.880465442372845, -87.75634710267644)
#
# 6/10 positive, 10/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# y
# DBA Name : hudson news
# AKA Name : hudson news t-1 gate b5
# Facility Type : grocery store
# Address : 11601 w touhy ave
# City : chicago
# Zip : 60666
# LatLong : (42.008536400868735, -87.91442843927048)
#
# DBA Name : hudson news
# AKA Name : hudson news/t1 b-11
# Facility Type : store
# Address : 11601 w touhy ave
# City : chicago
# Zip : 60666
# LatLong : (42.008536400868735, -87.91442843927048)
#
# 7/10 positive, 10/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# n
# DBA Name : harolds 57
# AKA Name : harolds 57
# Facility Type : restaurant
# Address : 7113 s state st
# City : chicago
# Zip : 60619
# LatLong : (41.7650677789878, -87.62475001172706)
#
# DBA Name : harolds chicken shack 6
# AKA Name : harolds chicken shack 6
# Facility Type : None
# Address : 7139 s state st
# City : chicago
# Zip : 60619
# LatLong : (41.76435396706882, -87.62473563971668)
#
# 7/10 positive, 11/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# n
# DBA Name : i dream of falafel
# AKA Name : i dream of falafel
# Facility Type : restaurant
# Address : 112 w monroe st
# City : chicago
# Zip : 60603
# LatLong : (41.880801065513246, -87.63126132290381)
#
# DBA Name : i dream of falafel
# AKA Name : i dream of falafel
# Facility Type : restaurant
# Address : 555 w monroe st
# City : chicago
# Zip : 60661
# LatLong : (41.880447908791545, -87.64183897534404)
#
# 7/10 positive, 12/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# n
# DBA Name : bias cafeteria marianao ii
# AKA Name : bias cafe
# Facility Type : restaurant
# Address : 6401 w addison st
# City : chicago
# Zip : 60634
# LatLong : (41.94555292295917, -87.78636821200944)
#
# DBA Name : taco madre
# AKA Name : None
# Facility Type : restaurant
# Address : 6401 w addison st
# City : chicago
# Zip : 60634
# LatLong : (41.94555292295917, -87.78636821200944)
#
# 7/10 positive, 13/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# n
# DBA Name : burger joint chicago bar grill llc
# AKA Name : None
# Facility Type : restaurant
# Address : 500 w madison st
# City : chicago
# Zip : 60661
# LatLong : (41.88199433820508, -87.6397586848809)
#
# DBA Name : k r lobby shop
# AKA Name : k r lobby shop
# Facility Type : grocery store
# Address : 500 w monroe st
# City : chicago
# Zip : 60661
# LatLong : (41.880699246124394, -87.63972502663869)
#
# 7/10 positive, 14/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# n
# DBA Name : the baby academy
# AKA Name : the baby academy
# Facility Type : childrens services facility
# Address : 8605-8607 s cottage grove ave
# City : chicago
# Zip : 60619
# LatLong : (41.738261523797966, -87.6047230763477)
#
# DBA Name : the baby academy
# AKA Name : the baby academy
# Facility Type : daycare (under 2 years)
# Address : 8607 s cottage grove ave
# City : chicago
# Zip : 60619
# LatLong : (41.7382052478746, -87.60472164419079)
#
# 7/10 positive, 15/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# y
# DBA Name : happy panda inc.
# AKA Name : 18th st. asian bistro
# Facility Type : restaurant
# Address : 1343 w 18th st
# City : chicago
# Zip : 60608
# LatLong : (41.85777810023129, -87.6605884280591)
#
# DBA Name : wongs asia cafe
# AKA Name : 18th street asian bistro
# Facility Type : restaurant
# Address : 1343 w 18th st
# City : chicago
# Zip : 60608
# LatLong : (41.85777810023129, -87.6605884280591)
#
# 8/10 positive, 15/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# y
# DBA Name : quest food management services
# AKA Name : latin school
# Facility Type : restaurant
# Address : 59 w north blvd
# City : chicago
# Zip : 60610
# LatLong : (41.91108516003885, -87.63125957941122)
#
# DBA Name : quest food management services
# AKA Name : latin school
# Facility Type : restaurant
# Address : 45 w north blvd
# City : chicago
# Zip : 60610
# LatLong : (41.911085151800144, -87.63063210150685)
#
# 9/10 positive, 15/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# y
# DBA Name : early childhood educare center
# AKA Name : None
# Facility Type : daycare above and under 2 years
# Address : 5055 s state
# City : chicago
# Zip : 60609
# LatLong : (41.80214349010087, -87.62574740239889)
#
# DBA Name : attucks
# AKA Name : attucks
# Facility Type : school
# Address : 5055 s state
# City : chicago
# Zip : 60609
# LatLong : (41.80214349010087, -87.62574740239889)
#
# 10/10 positive, 15/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# u
# DBA Name : la esperanza restaurant
# AKA Name : la esperanza restaurant
# Facility Type : restaurant
# Address : 1864 s blue island ave
# City : chicago
# Zip : 60608
# LatLong : (41.856306651100724, -87.66265894498156)
#
# DBA Name : la esperanza restuarant
# AKA Name : la esperanza restuarant
# Facility Type : None
# Address : 1864 s blue island ave
# City : chicago
# Zip : 60608
# LatLong : (41.856306651100724, -87.66265894498156)
#
# 10/10 positive, 15/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# y
# DBA Name : el original gallo bravo
# AKA Name : el original gallo bravo
# Facility Type : restaurant
# Address : 4503-4505 n kedzie ave
# City : chicago
# Zip : 60625
# LatLong : (41.96315679416602, -87.70815959668909)
#
# DBA Name : el original gallo bravo
# AKA Name : el gallo bravo
# Facility Type : restaurant
# Address : 4503 n kedzie ave
# City : chicago
# Zip : 60625
# LatLong : (41.96315679416602, -87.70815959668909)
#
# 11/10 positive, 15/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# y
# DBA Name : smart learning center llc
# AKA Name : smart learning center
# Facility Type : after school program
# Address : 2839-2841 s archer ave
# City : chicago
# Zip : 60608
# LatLong : (41.842695478349206, -87.65550921697735)
#
# DBA Name : smart learning center llc
# AKA Name : smart learning center llc
# Facility Type : childern activity facility
# Address : 2841 s archer ave
# City : chicago
# Zip : 60608
# LatLong : (41.842662462230905, -87.6555778185462)
#
# 12/10 positive, 15/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# f
# Finished labeling
# /home/oskar/.local/lib/python3.6/site-packages/dedupe/core.py:151: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# clustering...
# /home/oskar/.local/lib/python3.6/site-packages/dedupe/core.py:151: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# # duplicate sets 1627

# %%
locations_dedup[~pd.isna(locations_dedup['cluster id'])]
# Out:
#                        DBA Name                  AKA Name  \
# 13        smart child preschool     smart child preschool
# 17     idof fresh mediterranean  idof fresh mediterranean
# 19                       gopuff                    gopuff
# 19            subway restaurant                    subway
# 54                   the market                the market
# ...                         ...                       ...
# 57536              under the el              mixed greens
# 57954        rose food mart inc            rose food mart
# 58218               pizza mania               pizza mania
# 58671           dollar deals up           dollar deals up
# 58675           dollar deals up           dollar deals up
#
#                  Facility Type                  Address     City    Zip  \
# 13     15 monts to 5 years old        5100 w foster ave  chicago  60630
# 17                  restaurant       6558 n sheridan rd  chicago  60626
# 19               grocery store        1801 w warner ave  chicago  60613
# 19                  restaurant        953 w webster ave  chicago  60614
# 54                  restaurant        5700 s cicero ave  chicago  60638
# ...                        ...                      ...      ...    ...
# 57536               restaurant            223 w lake st  chicago  60606
# 57954            grocery store    11300 s wentworth ave  chicago  60628
# 58218                     None         5777 n ridge ave  chicago  60660
# 58671            grocery store  2057- 2059 n pulaski rd  chicago  60639
# 58675                     None  2057- 2059 n pulaski rd  chicago  60639
#
#                                         LatLong  cluster id  confidence
# 13     (41.975354698580844, -87.75534848899322)         0.0    0.619474
# 17     (42.001798790886504, -87.66090125470284)         1.0    0.769347
# 19     (41.956845683288854, -87.67439466946578)         2.0    0.789743
# 19     (41.921633711055094, -87.65317221940548)         2.0    0.789743
# 54      (41.78932932326538, -87.74164564419638)         3.0    0.800028
# ...                                         ...         ...         ...
# 57536  (41.885621553750475, -87.63480048875809)      1580.0    0.538934
# 57954    (41.6888459802589, -87.62794434817805)       541.0    0.797941
# 58218  (41.987061183467176, -87.66544832642705)       499.0    0.807182
# 58671  (41.918891263940395, -87.72646531498671)      1559.0    0.819209
# 58675  (41.918891263940395, -87.72646531498671)      1559.0    0.819209
#
# [4188 rows x 9 columns]

# %%
# ## Writing Results

# Write our original data back out to a CSV with a new column called 
# 'Cluster ID' which indicates which records refer to each other.

cluster_membership = {}
cluster_id = 0
for (cluster_id, cluster) in enumerate(clustered_dupes):
    id_set, scores = cluster
    cluster_d = [data_d[c] for c in id_set]
    canonical_rep = dedupe.canonicalize(cluster_d)
    for record_id, score in zip(id_set, scores):
        cluster_membership[record_id] = {
            "cluster id" : cluster_id,
            "canonical representation" : canonical_rep,
            "confidence": score
        }
